# %% [markdown]
# # Linear Regression on Real State Price Prediction Dataset

# %% [markdown]
# # Step 1: Import important libraries

# %%
#import libraries
import numpy
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
# %matplotlib inline

# %% [markdown]
# # Step 2: Import the dataset and Extract independent and dependent variables

# %%
# extrac independent and dependent variables
X = dataset.iloc[:,:-1].values
Y = dataset.iloc[:, -1].values

dataset.head()
# Out:
#    X1 transaction date  X2 house age  X3 distance to the nearest MRT station  \
# 0             2012.917          32.0                                84.87882
# 1             2012.917          19.5                               306.59470
# 2             2013.583          13.3                               561.98450
# 3             2013.500          13.3                               561.98450
# 4             2012.833           5.0                               390.56840
#
#    X4 number of convenience stores  X5 latitude  X6 longitude  \
# 0                               10     24.98298     121.54024
# 1                                9     24.98034     121.53951
# 2                                5     24.98746     121.54391
# 3                                5     24.98746     121.54391
# 4                                5     24.97937     121.54245
#
#    Y house price of unit area
# 0                        37.9
# 1                        42.2
# 2                        47.3
# ...

# %% [markdown]
# # Step 3: Visualize the dataset in a correlation matrix

# %%
sns.heatmap(dataset.corr())
# Out:
# <Axes: >

# %% [markdown]
# # Step 4: Encoding Categorical data¶

# %%
# label_encoder = LabelEncoder()
# X[:, 3] = label_encoder.fit_transform(X[:, -1])

# one_hot_encoder = OneHotEncoder()
# X = one_hot_encoder.fit_transform(X).toarray()
# print(X[0])

# %% [markdown]
# # Step 5: avoid dummy variable trap

# %%
# X = X[:,1:]

# %% [markdown]
# # Step 6: split train and test data

# %%
# Split the dataset into training and testing sets
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=1)

# %%
X_train, X_test, Y_train, Y_test
# Out:
# (array([[2.0126670e+03, 1.5500000e+01, 8.1593140e+02, 4.0000000e+00,
#          2.4978860e+01, 1.2153464e+02],
#         [2.0129170e+03, 8.0000000e+00, 1.0481010e+02, 5.0000000e+00,
#          2.4966740e+01, 1.2154067e+02],
#         [2.0133330e+03, 6.3000000e+00, 9.0456060e+01, 9.0000000e+00,
#          2.4974330e+01, 1.2154310e+02],
#         ...,
#         [2.0126670e+03, 3.7100000e+01, 9.1863570e+02, 1.0000000e+00,
#          2.4971980e+01, 1.2155063e+02],
#         [2.0127500e+03, 1.2900000e+01, 2.5063100e+02, 7.0000000e+00,
#          2.4966060e+01, 1.2154297e+02],
#         [2.0131670e+03, 1.2000000e+01, 1.3601390e+03, 1.0000000e+00,
#          2.4952040e+01, 1.2154842e+02]]),
#  array([[2.0135000e+03, 1.0400000e+01, 2.2519380e+03, 4.0000000e+00,
#          2.4959570e+01, 1.2151353e+02],
#         [2.0130830e+03, 1.1000000e+00, 1.9358450e+02, 6.0000000e+00,
#          2.4965710e+01, 1.2154089e+02],
#         [2.0130000e+03, 8.9000000e+00, 3.0781760e+03, 0.0000000e+00,
# ...

# %% [markdown]
# # step 7: Fit Multiple linear regression to training set

# %%
#fitting nultiple linear regression to the training set
regressor = LinearRegression()
regressor.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # step 8: predict the test set

# %%
#predict the test set results
Y_predict = regressor.predict(X_test)
Y_predict
# Out:
# array([34.79742428, 47.46521888, 20.92649905, 12.44066887, 42.96379361,
#        34.74573027, 31.04247971, 45.54751177, 37.82067836, 13.75947347,
#        11.93297924, 38.39381127, 31.93092108, 45.46667102, 50.93522403,
#        36.30036154, 44.39307916, 45.09388121, 29.88922181, 43.9352825 ,
#        51.50141664, 28.29865035, 40.17210353, 46.98674853, 45.65710115,
#        27.92775475, 30.98685655, 47.60814939, 46.06040453, 15.1867402 ,
#        33.78086918, 34.84166227, 42.27618027, 44.84930889, 48.12439262,
#        12.87264524, 41.12137596, 41.15743598, 39.01226777, 13.32063367,
#        38.96468765, 24.28892917, 54.5683122 , 36.63436327, 35.05528108,
#        38.90466568, 30.86413555, 39.74778575, 45.97577573, 34.40090764,
#        11.46829234, 44.47815665, 45.13134611, 14.03091125, 48.87082594,
#        42.43173988, 44.39307916, 39.3848415 , 38.1082736 , 39.59258161,
#        25.20621826, 40.08960644, 35.34085094, 12.87264524, 40.23555771,
# ...

# %% [markdown]
# # step 9: calculate the coefficient and intercept

# %%
#calculating the cofficients
regressor.coef_
# Out:
# array([ 5.71714218e+00, -2.49326467e-01, -4.93769843e-03,  1.07614509e+00,
#         2.27037100e+02, -3.56988335e+01])

# %%
# calculating the intercept
regressor.intercept_
# Out:
# -12796.117684899227

# %% [markdown]
# # step 10: evaluate the model

# %%
r2_score(Y_test, Y_predict)
# Out:
# 0.7034608498765477
